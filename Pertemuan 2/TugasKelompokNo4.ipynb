# %% [markdown]
# <a href="https://colab.research.google.com/github/NajwaaAzzahra/Machine_Learning/blob/main/Pertemuan%202/TugasKelompokNo4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Tugas Kelompok No. 4
# #Kelompok 3
# 1. Ahmad Faza Alfan Fashlah
# 2. Muhammad Fakhruddin Arif
# 3. Rizqi Reza Danuarta
# 4. Najwa Azzahra

# %% [markdown]
# Pada tugas pratikum ini Anda akan menggunakan data "Wisconsin Breast Cancer". Data tersebut terdiri dari 569 data yang digunakan untuk mendiagnonis jenis kanker Malignant (M) dan Benign (B)

# %% [markdown]
# 1. Pisahkan antara variabel yang dapat digunakan dan variabel yang tidak dapat digunakan.

# %%
import pandas as pd

data = 'wbc.csv' # path dataset
df = pd.read_csv(data) # load dataset

df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    ...  texture_worst  perimeter_worst  area_worst  smoothness_worst  \
# 0  ...          17.33           184.60      2019.0            0.1622
# 1  ...          23.41           158.80      1956.0            0.1238
# 2  ...          25.53           152.50      1709.0            0.1444
# 3  ...          26.50            98.87       567.7            0.2098
# 4  ...          16.67           152.20      1575.0            0.1374
#
#    compactness_worst  concavity_worst  concave points_worst  symmetry_worst  \
# 0             0.6656           0.7119                0.2654          0.4601
# 1             0.1866           0.2416                0.1860          0.2750
# 2             0.4245           0.4504                0.2430          0.3613
# 3             0.8663           0.6869                0.2575          0.6638
# 4             0.2050           0.4000                0.1625          0.2364
#
#    fractal_dimension_worst  Unnamed: 32
# 0                  0.11890          NaN
# 1                  0.08902          NaN
# 2                  0.08758          NaN
# 3                  0.17300          NaN
# 4                  0.07678          NaN
#
# [5 rows x 33 columns]

# %%
df = df[['diagnosis', 'radius_mean', 'smoothness_mean', 'texture_worst', 'smoothness_worst']]
df.head()
# Out:
#   diagnosis  radius_mean  smoothness_mean  texture_worst  smoothness_worst
# 0         M        17.99          0.11840          17.33            0.1622
# 1         M        20.57          0.08474          23.41            0.1238
# 2         M        19.69          0.10960          25.53            0.1444
# 3         M        11.42          0.14250          26.50            0.2098
# 4         M        20.29          0.10030          16.67            0.1374

# %% [markdown]
# 2. Lakukan proses encoding pada kolom "diagnosis".

# %%
from sklearn.preprocessing import LabelEncoder #import library

le = LabelEncoder() # membuat objek dari LabelEncoder

df['diagnosis'] = le.fit_transform(df['diagnosis']) # proses encoding

df.head() # menampilkan data
# Out:
#    diagnosis  radius_mean  smoothness_mean  texture_worst  smoothness_worst
# 0          1        17.99          0.11840          17.33            0.1622
# 1          1        20.57          0.08474          23.41            0.1238
# 2          1        19.69          0.10960          25.53            0.1444
# 3          1        11.42          0.14250          26.50            0.2098
# 4          1        20.29          0.10030          16.67            0.1374

# %% [markdown]
# 3. Lakukan proses standarisasi pada semua kolom yang memiliki nilai numerik.

# %%
from sklearn.preprocessing import StandardScaler #import library

std = StandardScaler()
df['radius_mean'] = std.fit_transform(df[['radius_mean']])
df['smoothness_mean'] = std.fit_transform(df[['smoothness_mean']])
df['texture_worst'] = std.fit_transform(df[['texture_worst']])
df['smoothness_worst'] = std.fit_transform(df[['smoothness_worst']])

df.head() # menampilkan data
# Out:
#    diagnosis  radius_mean  smoothness_mean  texture_worst  smoothness_worst
# 0          1     1.097064         1.568466      -1.359293          1.307686
# 1          1     1.829821        -0.826962      -0.369203         -0.375612
# 2          1     1.579888         0.942210      -0.023974          0.527407
# 3          1    -0.768909         3.283553       0.133984          3.394275
# 4          1     1.750297         0.280372      -1.466770          0.220556

# %% [markdown]
# 4. Lakukan proses stratified split data untuk membuat data latih dan data uji dengan rasio 80:20.

# %%
import pandas as pd

# Split data
from sklearn.model_selection import train_test_split

# Split data training dan dan lainnya
# data lainnya, akan kita split lagi menjadi validasi dan testing.
# Rasio yang akan kita gunakan adalah 8:1:1
df_train, df_unseen = train_test_split(df, test_size=0.2, random_state=0, stratify=df['diagnosis'])

# Split lagi antara validasi dan testing
df_val, df_test = train_test_split(df_unseen, test_size=0.5, random_state=0, stratify=df_unseen['diagnosis'])

# Cek masing-masing ukuran data

print(f'Jumlah label data asli:\n{df.diagnosis.value_counts()}')
print(f'Jumlah label data train:\n{df_train.diagnosis.value_counts()}')
print(f'Jumlah label data val:\n{df_val.diagnosis.value_counts()}')
print(f'Jumlah label data test:\n{df_test.diagnosis.value_counts()}')
# Out:
# Jumlah label data asli:
# diagnosis
# 0    357
# 1    212
# Name: count, dtype: int64
# Jumlah label data train:
# diagnosis
# 0    285
# 1    170
# Name: count, dtype: int64
# Jumlah label data val:
# diagnosis
# 0    36
# 1    21
# Name: count, dtype: int64
# Jumlah label data test:
# diagnosis
# 0    36
# 1    21
# Name: count, dtype: int64
